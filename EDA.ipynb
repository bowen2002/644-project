# %% [markdown]
# You are generating a Phase I (Part 1) notebook for DS444 team project.
# Goal: support a 2–3 slide proposal defense by describing the dataset and visualizing relationships between predictors and outcome.
# DO NOT train any ML models, DO NOT split train/test, DO NOT report RMSE/R2. Only data understanding + light cleaning + EDA plots.
#
# Dataset file path (local): /mnt/data/AB_NYC_2019.csv
#
# Task requirements (must include):
# 1) Load data with pandas. Print:
#    - df.shape (rows, columns)
#    - df.head(5)
#    - df.info()
#    - Missing values count per column (df.isna().sum()) and missing percentage.
# 2) Define the prediction problem clearly in markdown:
#    - Outcome variable y = 'price' (continuous)
#    - Candidate predictors X:
#      numeric = ['latitude','longitude','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']
#      categorical = ['neighbourhood_group','room_type']
#    - Briefly explain why predicting nightly price matters (hosts/platform/guests).
# 3) Light data cleaning for Phase I only (keep it minimal and explain):
#    - Convert price to numeric if needed.
#    - Handle missing values:
#        * Fill 'reviews_per_month' missing with 0 (or explain alternative).
#        * Drop rows with missing 'price' if any.
#    - Optional: Create a log-transformed target y_log = log1p(price) for visualization only; keep original price too.
#    - Optional outlier handling for plots only: cap price at 99th percentile or filter price <= 500, but clearly state it is only for visualization clarity.
# 4) Descriptive statistics:
#    - df['price'].describe()
#    - grouped summaries:
#        * mean/median price by 'room_type'
#        * mean/median price by 'neighbourhood_group'
# 5) Visualizations (at least 3, labeled, with titles and axis labels):
#    A) Histogram of price (and/or log1p(price)) to show distribution.
#    B) Boxplot of price by room_type.
#    C) Boxplot (or bar with median) of price by neighbourhood_group.
#    D) Scatter plot of latitude vs longitude colored by price (optional, if simple).
#    For all plots: use matplotlib (seaborn optional), set figure size, rotate x tick labels if needed.
# 6) Close with a short markdown section "Key early insights (Phase I)" listing 3–5 bullet points referencing what the plots show (e.g., Manhattan higher prices, entire home/apt higher than private room, etc.).
#
# Output: a single Python notebook style script with markdown comments and code cells separated by clear headings.
# Make the code runnable as-is in a standard Python environment with pandas, numpy, matplotlib installed.
